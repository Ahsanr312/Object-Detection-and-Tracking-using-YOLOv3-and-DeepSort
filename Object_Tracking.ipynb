# %%
## Checks which GPU is assigned to you
# !nvidia-smi

# %%
## Go to the Object Tracking Folder on Drive and install requirements needed for the project
import sys
sys.path.append('/content/drive/My Drive/Object Tracking')
# !pip install -r '/content/drive/My Drive/Object Tracking/requirements-gpu.txt'

# %%
## Setting up NVIDIA Driver
# !sudo add-apt-repository ppa:graphics-drivers/ppa
# !sudo apt install nvidia-driver-450

# %%
## Converting weights from Darknet to tensorflow
import sys
sys.path.append('/content/drive/My Drive/Object Tracking')

# !python '/content/drive/My Drive/Object Tracking/load_weights.py'  --weights '/content/yolov3.weights' --output '/content/drive/My Drive/Object Tracking/weights/yolov3-custom.tf' --num_classes 80

# %%
## Executing Object Detection and Tracking on Video
import sys
sys.path.append('/content/drive/My Drive/Object Tracking')

# !python '/content/drive/My Drive/Object Tracking/object_tracker.py' --video '/content/drive/My Drive/Object Tracking/data/video/Vid_1.avi' --output '/content/drive/My Drive/Object Tracking/data/video/Output_Vid_1.avi' --weights '/content/drive/My Drive/Object Tracking/weights/yolov3-custom.tf' --num_classes 80 --classes '/content/drive/My Drive/Object Tracking/data/labels/coco.names'
